# %%
from datetime import date
import papermill as pm

today = date.today()

# %%
config='TROPICO12'
case='TRPC12N00'
year='2012'
plots_surf=False
plot_eke=True
plot_rms=True
plot_psi=True
plots_100m=True
plots_1000m=True
pm.execute_notebook('2021-03-17-AA-single-map-yearly-mean-surface-fields.ipynb',
                    'outputs/'+str(today)+'output_map_surface_yearly_means_'+config+'-'+case+'-'+year+'.ipynb',
                    parameters=dict(config=config,case=case,year=year,plots_surf=plots_surf,plot_eke=plot_eke,plot_rms=plot_rms,plot_psi=plot_psi,plots_100m=plots_100m,plots_1000m=plots_1000m))
# Out:
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': 'native-sleeping',
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-18T09:41:22.318490',
#      'end_time': '2021-03-18T09:41:22.331224',
#      'duration': 0.012734,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-03-18T09:41:22.328698Z',
#      'iopub.execute_input': '2021-03-18T09:41:22.329235Z',
#      'shell.execute_reply': '2021-03-18T09:41:22.330557Z',
#      'iopub.status.idle': '2021-03-18T09:41:22.331053Z'}},
#    'outputs': [],
#    'source': "config='CALEDO60'\ncase='TRPC12N00'\nyear='2012'"},
#   {'id': 'historic-darkness',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-18T09:41:22.339316',
#      'end_time': '2021-03-18T09:41:22.350462',
# ...

# %%
config='CALEDO60'
case='TRPC12N00'
year='2012'
plots_surf=False
plot_eke=True
plot_rms=True
plot_psi=True
plots_100m=True
plots_1000m=Truepm.execute_notebook('2021-03-17-AA-single-map-yearly-mean-surface-fields.ipynb',
                    'outputs/'+str(today)+'output_map_surface_yearly_means_'+config+'-'+case+'-'+year+'.ipynb', 
                    parameters=dict(config=config,case=case,year=year,plots_surf=plots_surf,plot_eke=plot_eke,plot_rms=plot_rms,plot_psi=plot_psi,plots_100m=plots_100m,plots_1000m=plots_1000m))
# Out:
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': 'native-sleeping',
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-18T09:47:30.622501',
#      'end_time': '2021-03-18T09:47:30.635279',
#      'duration': 0.012778,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-03-18T09:47:30.632816Z',
#      'iopub.execute_input': '2021-03-18T09:47:30.633337Z',
#      'iopub.status.idle': '2021-03-18T09:47:30.634636Z',
#      'shell.execute_reply': '2021-03-18T09:47:30.635055Z'}},
#    'outputs': [],
#    'source': "config='CALEDO60'\ncase='TRPC12N00'\nyear='2012'"},
#   {'id': 'brave-persian',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-18T09:47:30.643509',
#      'end_time': '2021-03-18T09:47:30.654924',
# ...

# %%
config='TROPICO12'
case='TRPC12N00'
year='2012'
plots_surf=False
plot_eke=True
plot_rms=True
plot_psi=True
plots_100m=True
pm.execute_notebook('2021-03-17-AA-only-map-monthly-mean-surface-fields.ipynb',
                    'outputs/'+str(today)+'output_map_surface_monthly_means_'+config+'-'+case+'-'+year+'.ipynb',
                    parameters=dict(config=config,case=case,year=year,plots_surf=plots_surf,plot_eke=plot_eke,plot_rms=plot_rms,plot_psi=plot_psi,plots_100m=plots_100m,plots_1000m=plots_1000m))
# Out:
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': 'geographic-warren',
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-18T09:58:52.337062',
#      'end_time': '2021-03-18T09:58:52.349929',
#      'duration': 0.012867,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-03-18T09:58:52.347267Z',
#      'iopub.execute_input': '2021-03-18T09:58:52.347810Z',
#      'iopub.status.idle': '2021-03-18T09:58:52.349257Z',
#      'shell.execute_reply': '2021-03-18T09:58:52.349677Z'}},
#    'outputs': [],
#    'source': "config='CALEDO60'\ncase='TRPC12N00'\nyear='2012'"},
#   {'id': 'excellent-converter',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-18T09:58:52.358456',
#      'end_time': '2021-03-18T09:58:52.370441',
# ...

# %%
config='CALEDO60'
case='TRPC12N00'
year='2012'
plots_surf=False
plot_eke=True
plot_rms=True
plot_psi=True
plots_100m=True
pm.execute_notebook('2021-03-17-AA-only-map-monthly-mean-surface-fields.ipynb',
                    'outputs/'+str(today)+'output_map_surface_monthly_means_'+config+'-'+case+'-'+year+'.ipynb',
                    parameters=dict(config=config,case=case,year=year,plots_surf=plots_surf,plot_eke=plot_eke,plot_rms=plot_rms,plot_psi=plot_psi,plots_100m=plots_100m,plots_1000m=plots_1000m))
