# %%
from datetime import date
import papermill as pm

today = date.today()

# %%
case='TRPC12N00'
year='2012'
pm.execute_notebook('2021-02-25-AA-map-yearly-mean-surface-fields-tropico.ipynb','outputs/'+str(today)+'output_map_surface_yearly_means_TROPICO12-'+case+'-'+year+'.ipynb',parameters=dict(case=case,year=year))
# Out:
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': 'educated-vegetable',
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-03T16:54:15.745039',
#      'end_time': '2021-03-03T16:54:15.758403',
#      'duration': 0.013364,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-03-03T16:54:15.755821Z',
#      'iopub.execute_input': '2021-03-03T16:54:15.756335Z',
#      'iopub.status.idle': '2021-03-03T16:54:15.757751Z',
#      'shell.execute_reply': '2021-03-03T16:54:15.758160Z'}},
#    'outputs': [],
#    'source': "case='TRPC12N00'\nyear='2012'"},
#   {'id': 'clean-christianity',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-03T16:54:15.766888',
#      'end_time': '2021-03-03T16:54:15.778892',
#      'duration': 0.012004,
# ...

# %%
case='TRPC12N00'
year='2012'
pm.execute_notebook('2021-02-25-AA-map-yearly-mean-surface-fields-caledo.ipynb','outputs/'+str(today)+'output_map_surface_yearly_means_CALEDO60-'+case+'-'+year+'.ipynb',parameters=dict(case=case,year=year))
# Out:
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': 'another-establishment',
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-03T17:03:01.215280',
#      'end_time': '2021-03-03T17:03:01.228231',
#      'duration': 0.012951,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-03-03T17:03:01.225430Z',
#      'iopub.execute_input': '2021-03-03T17:03:01.225985Z',
#      'shell.execute_reply': '2021-03-03T17:03:01.227412Z',
#      'iopub.status.idle': '2021-03-03T17:03:01.228053Z'}},
#    'outputs': [],
#    'source': "case='TRPC12N00'\nyear='2012'"},
#   {'id': 'integral-recording',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-03T17:03:01.236505',
#      'end_time': '2021-03-03T17:03:01.248001',
#      'duration': 0.011496,
# ...
