# %%
from datetime import date
import papermill as pm

today = date.today()

# %%
case='TRPC12N00'
year='2012'
pm.execute_notebook('2021-02-25-AA-map-yearly-mean-surface-fields-tropico.ipynb','outputs/'+str(today)+'output_map_surface_yearly_means_TROPICO12-'+case+'-'+year+'.ipynb',parameters=dict(case=case,year=year),log_output=True)
# Out:
# Executing:   0%|          | 0/9 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': 'educated-vegetable',
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-09T14:45:51.808952',
#      'end_time': '2021-03-09T14:45:51.821618',
#      'duration': 0.012666,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-03-09T14:45:51.819043Z',
#      'iopub.execute_input': '2021-03-09T14:45:51.819564Z',
#      'iopub.status.idle': '2021-03-09T14:45:51.820974Z',
#      'shell.execute_reply': '2021-03-09T14:45:51.821390Z'}},
#    'outputs': [],
#    'source': "case='TRPC12N00'\nyear='2012'"},
#   {'id': 'hourly-authentication',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-09T14:45:51.830462',
#      'end_time': '2021-03-09T14:45:51.842093',
#      'duration': 0.011631,
# ...

# %%
case='TRPC12N00'
year='2012'
pm.execute_notebook('2021-02-25-AA-map-yearly-mean-surface-fields-caledo.ipynb','outputs/'+str(today)+'output_map_surface_yearly_means_CALEDO60-'+case+'-'+year+'.ipynb',parameters=dict(case=case,year=year))
# Out:
# Executing:   0%|          | 0/8 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'id': 'another-establishment',
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-09T15:04:00.701552',
#      'end_time': '2021-03-09T15:04:00.765626',
#      'duration': 0.064074,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-03-09T15:04:00.762819Z',
#      'iopub.execute_input': '2021-03-09T15:04:00.763365Z',
#      'shell.execute_reply': '2021-03-09T15:04:00.764803Z',
#      'iopub.status.idle': '2021-03-09T15:04:00.765449Z'}},
#    'outputs': [],
#    'source': "case='TRPC12N00'\nyear='2012'"},
#   {'id': 'intimate-assist',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-03-09T15:04:00.774550',
#      'end_time': '2021-03-09T15:04:00.787724',
#      'duration': 0.013174,
# ...
